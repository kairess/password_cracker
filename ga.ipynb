# %%
import random
import string

# %% [markdown]
# # Generate Population

# %%
password = 'brad1234'
min_len = 2
max_len = 10
# 엄마도 기억력의 한계가 있어서 비밀번호의 최대, 최소 자릿수를 지정해놓았다

def generate_word(length):
    result = ''
    x = ''.join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# 옛날 옛적 빵형이 지구에 빛이 있으라하여 첫번째 세대가 태어났다
def generate_population(size, min_len, max_len):
    population = []
    for i in range(size):
        # generate words with balanced length
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))
    return population

print(generate_word(length=10))
pop = generate_population(size=100, min_len=min_len, max_len=max_len)
pop
# Out:
# 3QKroWfpJk
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %% [markdown]
# # Fitness Function

# %%
def fitness(password, test_word):
    score = 0

    if len(password) != len(test_word):
        return score
    
    # if fit length, I'll give you score 0.5
    len_score = 0.5
    score += len_score

    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1

    # 백점 만점에 몇점?
    return score / (len(password) + len_score) * 100

fitness('abcde', 'abcde')
# Out:
# 100.0

# %% [markdown]
# # Compute Performance and Select Survivors

# %%
def compute_performace(population, password):
    performance_list = []
    for individual in population:
        score = fitness(password, individual)

        # we can predict length of password
        if score > 0:
            pred_len = len(individual)
        performance_list.append([individual, score])

    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])

    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for l in lucky_survivors:
        next_generation.append(l[0])
    
    # generate new population if next_generation is too small
    while len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    random.shuffle(next_generation)
    return next_generation

pop_sorted, pred_len = compute_performace(pop, password)
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, password_len=pred_len)

print('Password length must be %s' % pred_len)
survivors
# Out:
# Password length must be 8
# ['QV82n',
#  'j7SFqwXE',
#  'avnFWjO1',
#  'qkeoR2',
#  'wJVrZsdL',
#  'Qdm2',
#  '5BDEfU0k',
#  'DdfNewg',
#  'szIe9u2D',
#  'UjCIgtdW',
#  'wWEsyzjn',
#  '7SJbi09FI',
#  'cbJ456U8',
#  'UZVL8cO3',
#  'VEnSG',
#  'UDbem4qv',
#  '29fBHdwm',
#  'nax2B8',
#  'FeKwWPGS',
#  'SgH9y',
#  'j7SFqwXE',
#  'fo',
#  's4ECQcRf',
#  'MTdcyVPg',
#  'ZKrnGcMk',
#  '4gJwNe',
#  'UZVL8cO3',
#  'zKcC9ajw',
#  'u2YEyMvXk',
#  'fG1M9U8',
#  '4ruXSRfB',
#  'oh1u',
#  'ywiWfmKb',
#  '13',
#  'QxMt',
#  'CERdJtlV',
#  'Ovkg',
#  'HUg0',
#  'HO1r4',
#  'QAIH8WKC']

# %% [markdown]
# # Create Children

# %%
def create_child(individual1, individual2):
    child = ''
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100 * random.random()) < 50):
            child += individual1[i]
        else:
            child += individual2[i]
    return child

# 우리는 그렇게 자비롭지 않기때문에 부모를 내 맘대로 짝지어줄 것이다
def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) - 1 - i]))
    return next_population

children = create_children(survivors, 5)

children
# Out:
# ['QAIHn',
#  'QV82n',
#  'QA82n',
#  'QVI2n',
#  'QVI2n',
#  'j71rq',
#  'HO1F4',
#  'j71r4',
#  'H7Sr4',
#  'jOSr4',
#  'aUn0',
#  'HvnF',
#  'aUn0',
#  'HvgF',
#  'Hvn0',
#  'Ovko',
#  'Okkg',
#  'qkeg',
#  'qkeo',
#  'Okko',
#  'CJRrZtlV',
#  'CEVrZslV',
#  'CJRrJslL',
#  'wEVdJsdL',
#  'CJRdJslV',
#  'Qdm2',
#  'Qxmt',
#  'Qdm2',
#  'Qxmt',
#  'Qxm2',
#  '13',
#  '13',
#  '53',
#  '53',
#  '53',
#  'ywiWewK',
#  'ywiNewg',
#  'ydfNemK',
#  'ydfWewK',
#  'ydfNemK',
#  'sz1e',
#  'shIu',
#  'sz1e',
#  'oz1e',
#  'oz1e',
#  '4ruIStdW',
#  '4juIStdW',
#  '4ruXSRdW',
#  'UjCXSRfB',
#  'UrCXStdB',
#  'fWEs9Uj',
#  'wW1Myz8',
#  'wWEsyUj',
#  'fWEMyzj',
#  'wGEsyUj',
#  'uSJEyMvFI',
#  '72YEi09Xk',
#  'u2JEi09Xk',
#  'uSJbi09XI',
#  '7SJEi09XI',
#  'cbJ456Uw',
#  'cbc496j8',
#  'cbcC96Uw',
#  'cKJC5ajw',
#  'cKJC56Uw',
#  'UZVL8cO3',
#  'UZVL8cO3',
#  'UZVL8cO3',
#  'UZVL8cO3',
#  'UZVL8cO3',
#  '4EnSN',
#  'VgJSG',
#  'VEnSG',
#  '4gnwN',
#  '4gJwN',
#  'UKbem4qk',
#  'UKbem4Mv',
#  'ZKreGcMv',
#  'UDbnGcqv',
#  'UDrnmcMv',
#  'MTdBydPg',
#  'MTfBHdPg',
#  '2TdBydwm',
#  '29fBHVPg',
#  'M9fcHVwm',
#  'sax2Qc',
#  'naxCQc',
#  'n4ECQ8',
#  'naxCBc',
#  's4ECQc',
#  'Fo',
#  'fe',
#  'Fo',
#  'fe',
#  'fo',
#  'S7HFq',
#  'S7S9q',
#  'j7S9y',
#  'j7SFq',
#  'SgHFy']

# %% [markdown]
# # Mutation

# %%
def mutate_word(word):
    idx = int(random.random() * len(word))
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

new_generation = mutate_population(population=children, chance_of_mutation=10)

new_generation
# Out:
# ['QAIHn',
#  'QV82n',
#  'QA82F',
#  'QVI2n',
#  'QVI2n',
#  'j71rq',
#  'HO1F4',
#  'j71r4',
#  'H7Sr4',
#  'jOSr4',
#  'aUn0',
#  'HvKF',
#  'aUn0',
#  'HvgF',
#  'Hvn0',
#  'Ovko',
#  'Okkg',
#  'qkgg',
#  'qkeo',
#  'Okko',
#  'CJRrZtlV',
#  'CEVrZslV',
#  'CJRrJslL',
#  'wEVdJsdL',
#  'CJRdJslV',
#  'Qdm2',
#  'Qxmt',
#  'Qdm2',
#  'Qxmt',
#  'Qxm2',
#  '13',
#  '13',
#  '53',
#  '5s',
#  '53',
#  'ywiWewK',
#  'ywiNewg',
#  'yWfNemK',
#  'ydfWewK',
#  'ydfNemK',
#  'sz1e',
#  'shIu',
#  'sz1e',
#  'oz1e',
#  'oz1e',
#  '4ruIStdW',
#  '4juIStdW',
#  '4ruXSRdW',
#  'UjCXSRfB',
#  'UrCXStdB',
#  'fWEs9Uj',
#  'wW1Myz8',
#  'wWEsyUj',
#  'fWEMyzj',
#  'wGEsyUj',
#  'uSJEyMvFI',
#  '72YEi09Xk',
#  'u2JEi09Xk',
#  'uSJbi09XI',
#  '7SJ1i09XI',
#  'cbJ456Uw',
#  'cbc496j8',
#  'cbcC96Uw',
#  'cKJC5ajw',
#  'cKJC562w',
#  'UZVLRcO3',
#  'UfVL8cO3',
#  'UZVL8cO3',
#  'UZVL8cO3',
#  'UZVL8cO3',
#  '4EnSE',
#  'VgJSG',
#  'VEnSG',
#  '4gnwN',
#  '4gJwN',
#  'UKbem4qk',
#  'UKbem4Mv',
#  'ZKreGcMv',
#  'UDbnGcqv',
#  'UDrnmcMv',
#  'MTdBydPg',
#  'MTfBHdPg',
#  '2TdBydwm',
#  '29fBHVPg',
#  'M9fcHVwm',
#  'sax2Qc',
#  'naxCQc',
#  'n4ECQ8',
#  'naxCBc',
#  's4ECQc',
#  'Fo',
#  'fe',
#  'Fo',
#  're',
#  'fo',
#  'S7HFq',
#  'S7S9q',
#  'j7S9y',
#  'j7SFq',
#  'SgHFy']

# %% [markdown]
# # Test

# %%
password = 'bBanGhyONg'
n_generation = 300
population = 100
best_sample = 20
lucky_few = 20
n_child = 5
chance_of_mutation = 10

pop = generate_population(size=population, min_len=min_len, max_len=max_len)

for g in range(n_generation):
    pop_sorted, pred_len = compute_performace(population=pop, password=password)

    if int(pop_sorted[0][1]) == 100:
        print('SUCCESS! The password is %s' % (pop_sorted[0][0]))
        break
    
    survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)
    
    children = create_children(parents=survivors, n_child=n_child)

    new_generation = mutate_population(population=children, chance_of_mutation=10)
    
    pop = new_generation
    
    print('===== %sth Generation =====' % (g + 1))
    print(pop_sorted[0])
# Out:
# ===== 1th Generation =====
# ['p8st0RhdFC', 4.761904761904762]
# ===== 2th Generation =====
# ['SfRnWl2Kpr', 14.285714285714285]
# ===== 3th Generation =====
# ['ZTWnQl2xUU', 14.285714285714285]
# ===== 4th Generation =====
# ['MfInudcKuU', 14.285714285714285]
# ===== 5th Generation =====
# ['sXpnw9Mrm6', 14.285714285714285]
# ===== 6th Generation =====
# ['sXWnk9MrU6', 14.285714285714285]
# ===== 7th Generation =====
# ['sXWnQTEno6', 14.285714285714285]
# ===== 8th Generation =====
# ['s8Wnk9crUU', 14.285714285714285]
# ===== 9th Generation =====
# ['MXpnwTcnoU', 14.285714285714285]
# ===== 10th Generation =====
# ['s8Wnk9cro6', 14.285714285714285]
# ===== 11th Generation =====
# ['ZXpnk9Eno6', 14.285714285714285]
# ===== 12th Generation =====
# ['sXpnQ9EnU6', 14.285714285714285]
# ===== 13th Generation =====
# ['sXpnQ9Enog', 23.809523809523807]
# ===== 14th Generation =====
# ['sXWnz9cnog', 23.809523809523807]
# ===== 15th Generation =====
# ['sXWnzHcrvg', 23.809523809523807]
# ===== 16th Generation =====
# ['sXWnQ9crog', 23.809523809523807]
# ===== 17th Generation =====
# ['sXWnQHcOog', 33.33333333333333]
# ===== 18th Generation =====
# ['ZXWnQCcrog', 23.809523809523807]
# ===== 19th Generation =====
# ['sXWnQrcrog', 23.809523809523807]
# ===== 20th Generation =====
# ['Z8pnQCcnog', 23.809523809523807]
# ===== 21th Generation =====
# ['sXWnadcnKg', 23.809523809523807]
# ===== 22th Generation =====
# ['sXWnQHcnCg', 23.809523809523807]
# ===== 23th Generation =====
# ['sXWnaHcnog', 23.809523809523807]
# ===== 24th Generation =====
# ['sXWnadcnog', 23.809523809523807]
# ===== 25th Generation =====
# ['s8WnQdcnog', 23.809523809523807]
# ===== 26th Generation =====
# ['3XWna9inCg', 23.809523809523807]
# ===== 27th Generation =====
# ['sXWnQdi4og', 23.809523809523807]
# ===== 28th Generation =====
# ['fpWnQdOwog', 23.809523809523807]
# ===== 29th Generation =====
# ['sXWnadcnCg', 23.809523809523807]
# ===== 30th Generation =====
# ['s3WnaHinog', 23.809523809523807]
# ===== 31th Generation =====
# ['sXWnadinog', 23.809523809523807]
# ===== 32th Generation =====
# ['sXWnQdOnCg', 23.809523809523807]
# ===== 33th Generation =====
# ['sbWneHcnpg', 23.809523809523807]
# ===== 34th Generation =====
# ['sXWneHhnpg', 23.809523809523807]
# ===== 35th Generation =====
# ['3XTnQdinCg', 23.809523809523807]
# ===== 36th Generation =====
# ['sXWnQdinCg', 23.809523809523807]
# ===== 37th Generation =====
# ['bXWnadinCg', 33.33333333333333]
# ===== 38th Generation =====
# ['bXWnadinCg', 33.33333333333333]
# ===== 39th Generation =====
# ['bXWnadipog', 33.33333333333333]
# ===== 40th Generation =====
# ['bXWnQdEnpg', 33.33333333333333]
# ===== 41th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 42th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 43th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 44th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 45th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 46th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 47th Generation =====
# ['bXWnQdinNg', 42.857142857142854]
# ===== 48th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 49th Generation =====
# ['bXWneHinNg', 42.857142857142854]
# ===== 50th Generation =====
# ['bWWnedinNg', 42.857142857142854]
# ===== 51th Generation =====
# ['bXpnadinNg', 42.857142857142854]
# ===== 52th Generation =====
# ['bXWnedinNg', 42.857142857142854]
# ===== 53th Generation =====
# ['bXaned6nNg', 52.38095238095239]
# ===== 54th Generation =====
# ['bXaned6nNg', 52.38095238095239]
# ===== 55th Generation =====
# ['bXaned6nNg', 52.38095238095239]
# ===== 56th Generation =====
# ['bXanQdnnNg', 52.38095238095239]
# ===== 57th Generation =====
# ['bXaned9JNg', 52.38095238095239]
# ===== 58th Generation =====
# ['bXanQdnnNg', 52.38095238095239]
# ===== 59th Generation =====
# ['bXanedinNg', 52.38095238095239]
# ===== 60th Generation =====
# ['bXanedinNg', 52.38095238095239]
# ===== 61th Generation =====
# ['bXanadnnNg', 52.38095238095239]
# ===== 62th Generation =====
# ['bXanQdVnNg', 52.38095238095239]
# ===== 63th Generation =====
# ['b1anedinNg', 52.38095238095239]
# ===== 64th Generation =====
# ['b1anedYnNg', 52.38095238095239]
# ===== 65th Generation =====
# ['bXanQd6nNg', 52.38095238095239]
# ===== 66th Generation =====
# ['bXanQdnnNg', 52.38095238095239]
# ===== 67th Generation =====
# ['b1anQdnnNg', 52.38095238095239]
# ===== 68th Generation =====
# ['bXanQdinNg', 52.38095238095239]
# ===== 69th Generation =====
# ['b1anQd6nNg', 52.38095238095239]
# ===== 70th Generation =====
# ['b1anQd6nNg', 52.38095238095239]
# ===== 71th Generation =====
# ['bXanKd6nNg', 52.38095238095239]
# ===== 72th Generation =====
# ['b1anQd6nNg', 52.38095238095239]
# ===== 73th Generation =====
# ['bXanQd6nNg', 52.38095238095239]
# ===== 74th Generation =====
# ['bXaned6nNg', 52.38095238095239]
# ===== 75th Generation =====
# ['b1anQd6nNg', 52.38095238095239]
# ===== 76th Generation =====
# ['b1anQd6nNg', 52.38095238095239]
# ===== 77th Generation =====
# ['bXanQd6nNg', 52.38095238095239]
# ===== 78th Generation =====
# ['b1anQd6nNg', 52.38095238095239]
# ===== 79th Generation =====
# ['bXaned6nNg', 52.38095238095239]
# ===== 80th Generation =====
# ['bXanHd6nNg', 52.38095238095239]
# ===== 81th Generation =====
# ['bXanQdanNg', 52.38095238095239]
# ===== 82th Generation =====
# ['b1anQdanNg', 52.38095238095239]
# ===== 83th Generation =====
# ['bIanHd6nNg', 52.38095238095239]
# ===== 84th Generation =====
# ['bXaned6nNg', 52.38095238095239]
# ===== 85th Generation =====
# ['bXanxd6nNg', 52.38095238095239]
# ===== 86th Generation =====
# ['bXanxd6nNg', 52.38095238095239]
# ===== 87th Generation =====
# ['bXanQd6nNg', 52.38095238095239]
# ===== 88th Generation =====
# ['b1anedynNg', 61.904761904761905]
# ===== 89th Generation =====
# ['bXanQdynNg', 61.904761904761905]
# ===== 90th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 91th Generation =====
# ['bXanQdynNg', 61.904761904761905]
# ===== 92th Generation =====
# ['bXanQdynNg', 61.904761904761905]
# ===== 93th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 94th Generation =====
# ['bXanQdynNg', 61.904761904761905]
# ===== 95th Generation =====
# ['b1anQdynNg', 61.904761904761905]
# ===== 96th Generation =====
# ['bXangdynNg', 61.904761904761905]
# ===== 97th Generation =====
# ['bXancdynNg', 61.904761904761905]
# ===== 98th Generation =====
# ['bXangdynNg', 61.904761904761905]
# ===== 99th Generation =====
# ['bXanQdynNg', 61.904761904761905]
# ===== 100th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 101th Generation =====
# ['bDanxdynNg', 61.904761904761905]
# ===== 102th Generation =====
# ['bDanxdynNg', 61.904761904761905]
# ===== 103th Generation =====
# ['bXangdynNg', 61.904761904761905]
# ===== 104th Generation =====
# ['bXanxzynNg', 61.904761904761905]
# ===== 105th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 106th Generation =====
# ['bFangdynNg', 61.904761904761905]
# ===== 107th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 108th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 109th Generation =====
# ['bXanxzynNg', 61.904761904761905]
# ===== 110th Generation =====
# ['bXanxzynNg', 61.904761904761905]
# ===== 111th Generation =====
# ['bXanxgynNg', 61.904761904761905]
# ===== 112th Generation =====
# ['bXanxdy6Ng', 61.904761904761905]
# ===== 113th Generation =====
# ['bXanxzynNg', 61.904761904761905]
# ===== 114th Generation =====
# ['bFanxdynNg', 61.904761904761905]
# ===== 115th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 116th Generation =====
# ['bXanxdynNg', 61.904761904761905]
# ===== 117th Generation =====
# ['bFanxdynNg', 61.904761904761905]
# ===== 118th Generation =====
# ['bXanGdynNg', 71.42857142857143]
# ===== 119th Generation =====
# ['bXanGdynNg', 71.42857142857143]
# ===== 120th Generation =====
# ['bXanGdynNg', 71.42857142857143]
# ===== 121th Generation =====
# ['bXanxgyONg', 71.42857142857143]
# ===== 122th Generation =====
# ['bXanGhy2Ng', 80.95238095238095]
# ===== 123th Generation =====
# ['bXanxhyONg', 80.95238095238095]
# ===== 124th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 125th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 126th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 127th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 128th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 129th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 130th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 131th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 132th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 133th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 134th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 135th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 136th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 137th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 138th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 139th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 140th Generation =====
# ['bmanGhyONg', 90.47619047619048]
# ===== 141th Generation =====
# ['bmanGhyONg', 90.47619047619048]
# ===== 142th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 143th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 144th Generation =====
# ['bjanGhyONg', 90.47619047619048]
# ===== 145th Generation =====
# ['bganGhyONg', 90.47619047619048]
# ===== 146th Generation =====
# ['bganGhyONg', 90.47619047619048]
# ===== 147th Generation =====
# ['bXanGhyONg', 90.47619047619048]
# ===== 148th Generation =====
# ['bganGhyONg', 90.47619047619048]
# ===== 149th Generation =====
# ['b9anGhyONg', 90.47619047619048]
# ===== 150th Generation =====
# ['b9anGhyONg', 90.47619047619048]
# ===== 151th Generation =====
# ['bganGhyONg', 90.47619047619048]
# ===== 152th Generation =====
# ['b9anGhyONg', 90.47619047619048]
# ===== 153th Generation =====
# ['b9anGhyONg', 90.47619047619048]
# SUCCESS! The password is bBanGhyONg
